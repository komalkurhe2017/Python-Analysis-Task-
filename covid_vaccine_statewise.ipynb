# %%
import pandas as pd
import numpy as np

# %%
Data=pd.read_csv(r'C:\Users\Admin\Downloads\covid_vaccine_statewise.csv')

# %%
Data
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
Data.head()
# Out:
#    Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  India                   48276.0    3455.0   2957.0
# 1  17/01/2021  India                   58604.0    8532.0   4954.0
# 2  18/01/2021  India                   99449.0   13611.0   6583.0
# 3  19/01/2021  India                  195525.0   17855.0   7951.0
# 4  20/01/2021  India                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# 2                        NaN                          NaN
# ...

# %% [markdown]
# # Q6) Highest no. of dossed count in by vaccine by state

# %%
Data["State"].unique()
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
Data["State"]=Data["State"].replace("India","Maharashtra")
Data.head()
# Out:
#    Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0  16/01/2021  Maharashtra                   48276.0    3455.0   2957.0
# 1  17/01/2021  Maharashtra                   58604.0    8532.0   4954.0
# 2  18/01/2021  Maharashtra                   99449.0   13611.0   6583.0
# 3  19/01/2021  Maharashtra                  195525.0   17855.0   7951.0
# 4  20/01/2021  Maharashtra                  251280.0   25472.0  10504.0
#
#    First Dose Administered  Second Dose Administered  \
# 0                  48276.0                       0.0
# 1                  58604.0                       0.0
# 2                  99449.0                       0.0
# 3                 195525.0                       0.0
# 4                 251280.0                       0.0
#
#    Male (Doses Administered)  Female (Doses Administered)  \
# 0                        NaN                          NaN
# 1                        NaN                          NaN
# ...

# %%
df=Data.groupby('State')['Total Doses Administered'].sum().reset_index()
df
# Out:
#                                        State  Total Doses Administered
# 0                Andaman and Nicobar Islands              2.054441e+07
# 1                             Andhra Pradesh              1.591678e+09
# 2                          Arunachal Pradesh              6.093730e+07
# 3                                      Assam              7.163890e+08
# 4                                      Bihar              1.741293e+09
# 5                                 Chandigarh              5.629684e+07
# 6                               Chhattisgarh              9.681233e+08
# 7   Dadra and Nagar Haveli and Daman and Diu              3.818948e+07
# 8                                      Delhi              8.125584e+08
# 9                                        Goa              9.218954e+07
# 10                                   Gujarat              2.732064e+09
# 11                                   Haryana              9.144544e+08
# ...

# %%
highest=df.sort_values(['Total Doses Administered'], ascending=[False])
highest.head()
# Out:
#             State  Total Doses Administered
# 20    Maharashtra              3.851901e+10
# 33  Uttar Pradesh              3.342846e+09
# 10        Gujarat              2.732064e+09
# 28      Rajasthan              2.692747e+09
# 35    West Bengal              2.382597e+09

# %% [markdown]
# # Q7) Find top 20 state 2020 those taken vaccination inmale & female by state

# %%
df1=Dh=df1.sort_values(['Male(Individuals Vaccinated)'], ascending=[False])
ata.groupby('State')['Male(Individuals Vaccinated)'].sum().reset_index()
df1.head()
# Out:
#                          State  Male(Individuals Vaccinated)
# 0  Andaman and Nicobar Islands                           0.0
# 1               Andhra Pradesh                           0.0
# 2            Arunachal Pradesh                           0.0
# 3                        Assam                           0.0
# 4                        Bihar                           0.0

# %%
h=df1.sort_values(['Male(Individuals Vaccinated)'], ascending=[False])
h.head(10)
# Out:
#                           State  Male(Individuals Vaccinated)
# 20                  Maharashtra                  7.138699e+09
# 0   Andaman and Nicobar Islands                  0.000000e+00
# 1                Andhra Pradesh                  0.000000e+00
# 21                      Manipur                  0.000000e+00
# 22                    Meghalaya                  0.000000e+00
# 23                      Mizoram                  0.000000e+00
# 24                     Nagaland                  0.000000e+00
# 25                       Odisha                  0.000000e+00
# 26                   Puducherry                  0.000000e+00
# 27                       Punjab                  0.000000e+00

# %%
df2=Data.groupby('State')['Female(Individuals Vaccinated)'].sum().reset_index()
df2.head()
# Out:
#                          State  Female(Individuals Vaccinated)
# 0  Andaman and Nicobar Islands                             0.0
# 1               Andhra Pradesh                             0.0
# 2            Arunachal Pradesh                             0.0
# 3                        Assam                             0.0
# 4                        Bihar                             0.0

# %%
f=df2.sort_values(['Female(Individuals Vaccinated)'], ascending=[False])
f.head(10)
# Out:
#                           State  Female(Individuals Vaccinated)
# 20                  Maharashtra                    6.321629e+09
# 0   Andaman and Nicobar Islands                    0.000000e+00
# 1                Andhra Pradesh                    0.000000e+00
# 21                      Manipur                    0.000000e+00
# 22                    Meghalaya                    0.000000e+00
# 23                      Mizoram                    0.000000e+00
# 24                     Nagaland                    0.000000e+00
# 25                       Odisha                    0.000000e+00
# 26                   Puducherry                    0.000000e+00
# 27                       Punjab                    0.000000e+00

# %%
x=pd.concat((h,f))
x
# Out:
#                           State  Male(Individuals Vaccinated)  \
# 20                  Maharashtra                  7.138699e+09
# 0   Andaman and Nicobar Islands                  0.000000e+00
# 1                Andhra Pradesh                  0.000000e+00
# 21                      Manipur                  0.000000e+00
# 22                    Meghalaya                  0.000000e+00
# ..                          ...                           ...
# 12             Himachal Pradesh                           NaN
# 13            Jammu and Kashmir                           NaN
# 14                    Jharkhand                           NaN
# 15                    Karnataka                           NaN
# 35                  West Bengal                           NaN
#
#     Female(Individuals Vaccinated)
# 20                             NaN
# 0                              NaN
# 1                              NaN
# 21                             NaN
# 22                             NaN
# ...
